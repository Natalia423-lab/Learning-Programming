# %%
import numpy as np 

v = np.array([1,1])
print(v)
# Out:
# [1 1]

# %%
m = np.array([[1,1], [1,0]])
m
# Out:
# array([[1, 1],
#        [1, 0]])

# %%
import matplotlib.pyplot as plt 
plt.xlim(0, 3)
plt.ylim(0, 3)

plt.arrow(0, 0, v[0], v[1], head_width=.1, head_length=.2)

# %%
#FIXME: Figure out how to make the forumla work 

$$||x||_{2} = \sqrt{x_{1}^{2} + x_{2}^{2} + \cdots + x_{n}^{2}}$$
# Out:
#   Cell In[2], line 1
#     ||x||_{2} = \sqrt{x_{1}^{2} + x_{2}^{2} + \cdots + x_{n}^{2}}$$
#     ^
# SyntaxError: invalid syntax
